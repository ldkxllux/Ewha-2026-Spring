# %% [markdown]
# <a href="https://colab.research.google.com/github/ekyuho/Ewha-2026-Spring/blob/main/make_order.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

session=['04.13(월) 슬롯1', '04.16(목) 슬롯2', '04.16(목) 슬롯3','04.20(월) 슬롯4']
per_session=[4,4,5,5]

teams=[]
missing=[4]
for i in range(1,20):
  if i not in missing: teams.append(i)
print(teams)
random.shuffle(teams)
print(teams)
print(f'total {len(teams)}팀')

# 한슬롯당 5팀씩 진행하는 것으로 가정

count=0
for i in range(len(session)):
  print(session[i], end='')
  for j in range(per_session[i]):
    if count == len(teams): break
    print(f' {teams[count]}', end='')
    count+=1
  print()

# %%
import random

session=['04.30(목)']
per_session=[18]

teams=[]
missing=[4]
for i in range(1,20):
  if i not in missing: teams.append(i)
print(teams)
random.shuffle(teams)
print(teams)
print(f'total {len(teams)}팀')

# 한슬롯당 5팀씩 진행하는 것으로 가정

count=0
for i in range(len(session)):
  print(session[i], end='')
  for j in range(per_session[i]):
    if count == len(teams): break
    print(f' {teams[count]}', end='')
    count+=1
  print()

# %%
#기말
import random

session=['06.04(목) 슬롯1', '06.08(월) 슬롯2', '06.11(목) 슬롯3','06.15(월) 슬롯4']
per_session=[6,3,6,3]

teams=[]
missing=[4]
for i in range(1,20):
  if i not in missing: teams.append(i)
print(teams)
random.shuffle(teams)
print(teams)
print(f'total {len(teams)}팀')

# 한슬롯당 3팀씩 진행하는 것으로 가정

count=0
for i in range(len(session)):
  print(session[i], end='')
  for j in range(per_session[i]):
    if count == len(teams): break
    print(f' {teams[count]}', end='')
    count+=1
  print()
